# %% [markdown]
# <a href="https://colab.research.google.com/github/gaeldesenvolvedorgis-coder/basics_studies/blob/main/basic_estudy_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import geopandas as gpd

# %% [markdown]
# Apontando os caminhos dos dados shapefiles.

# %%
mun = '/content/drive/MyDrive/Colab/Dados/BR_Municipios_2025.shp'
reg_interd = '/content/drive/MyDrive/Colab/Dados/BR_RG_Intermediarias_2025.shp'
reg_imed = '/content/drive/MyDrive/Colab/Dados/BR_RG_Imediatas_2025.shp'

# %% [markdown]
# Reading the files in geodatabase

# %%
gpd_mun = gpd.read_file(mun)
gpd_reg_interd = gpd.read_file(reg_interd)
gpd_reg_imed = gpd.read_file(reg_imed)

# %% [markdown]
# Mapa das Regiões Intermediárias Brasileiras - IBGE

# %%
gpd_reg_interd.plot()
# Out:
# <Axes: >

# %% [markdown]
# Mapa das Regiões Imediatas Brasileiras - IBGE

# %%
gpd_reg_imed.plot()
# Out:
# <Axes: >

# %% [markdown]
# Mapa dos Municipios do Brasil - Instituto Brasileiro de Geografia e Estatística (IBGE)

# %%
gpd_mun.plot()
# Out:
# <Axes: >

# %% [markdown]
# **Next step is reserach abouth how change simbology from my maps. **
